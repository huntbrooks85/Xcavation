# %% [markdown]
# # 🪏 Xcavation Example 🪏

# %% [markdown]
# ### ⬇️ Import Relavent Packages ⬇️

# %%
# Import xcavation
from xcavation.genspec import *

# %% [markdown]
# ### 🏗️ Creates h5 Model Spectra Grid 🏗️

# %%
# MAIN TEST OBJECT
ra = 12.7955492
dec = -15.7382839

style = 'aperture'

# Call function with test input parameters
output = genspec(ra, dec, style, verification = True, threads = 12)

# %% [markdown]
# ### 🏁 Finé 🏁
